# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("C:/Users/USER/OneDrive/Desktop/myexcel.xlsx")
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
df=df.drop_duplicates()   # which means there is no duplicates of data present this dataset
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
df['Height'] = np.random.randint(150, 181, df.shape[0])

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     165     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     160     235
# 2     John Holland  Boston Celtics      30       SG   27     178     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     158     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     156     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     180     203
# 454      Raul Neto       Utah Jazz      25       PG   24     176     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     175     256
# 456    Jeff Withey       Utah Jazz      24        C   26     150     231
# 457       Priyanka       Utah Jazz      34        C   25     165     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# 1. Determine the distribution of employees across each team and calculate
# the percentage split relative to the total number of employees.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
team_counts=df['Team'].value_counts()
team_counts
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
explode = [0.1 if count == team_counts.max() else 0 for count in team_counts]

# %%
plt.figure(figsize=(10, 10))
plt.pie(team_counts, autopct='%1.1f%%', labels=team_counts.index, explode=explode)
plt.title('Distribution of Employees Across Teams')
plt.show()

# %% [markdown]
# 1.From this graph we can understand that 'New Orleans Pelicans' team has the higher employees(19) with 4.1% of total Employees.

# %% [markdown]
# 2.Second highest group with most employee is Memphis Grizzlies(18) with 3.9% of total employees.

# %% [markdown]
# 3.77% of teams have same number of employees(15).

# %% [markdown]
# 4.Orlando Magic and Minnesota Timberwolves Team have very least number of employees(14) with 3.1%.

# %% [markdown]
# 2. Segregate employees based on their positions within the company.

# %%
values=df['Position'].value_counts()
values
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
plot=sns.countplot(x=df['Position'])

#plot.bar_label(container=plot.containers[0],labels=values)

plt.title('Distribution of Employees Across Positions')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# 1.This is a graph of employee with different position and 'SG' is most common here around 102 employee were posted in this position

# %% [markdown]
# 2. The second most common post is 'PF' and around 100 employees were posted in this position and followed by 'PG'  with   92,'SF' with 85.

# %% [markdown]
# 3.very leat amount of employee were posted in 'C' with 79.

# %% [markdown]
# 3.Identify the predominant age group among employees.

# %%
age=df["Age"].value_counts()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

explode = [0.2 if count == age.max() else 0.05 for count in age]


plt.figure(figsize=(10,10))
plt.pie(age,labels=age.keys(),autopct='%2.1f%%',explode=explode)



plt.title('Distribution of Employees Across Age Groups')
plt.show()

# %% [markdown]
# 1.ABC company apponted empoyees with the age gap between 19 years to 40 years old.

# %% [markdown]
# 2.between 23 and 30 years old employees are the most dominent in this company

# %% [markdown]
# 3.Age 24 is predominant age group among employees.

# %% [markdown]
# 4.Discover which team and position have the highest salary expenditure

# %%
high_sal_team=df.groupby('Team')['Salary'].sum().reset_index()

# %%
plt.figure(figsize=(10, 6))
plt.bar(x='Team',height='Salary',data=high_sal_team,color='g')
for i in range(len(high_sal_team)):
    plt.text(high_sal_team['Team'][i], high_sal_team['Salary'][i] + 1, str(high_sal_team['Salary'][i]),
             ha='center',rotation='vertical',color='k')
plt.xticks(rotation=90)
plt.title('Salary Expenditure by Team')
plt.xlabel('Teams')
plt.ylabel('Total Salary Expenditure')
plt.show()

# %% [markdown]
# 1. From this graph we can clearly understand  the team 'Cleveland Cavaliers'  has the highest salary expenditure with 106988689

# %% [markdown]
# 2. The second highest team with salary expenditure team 'Los Angeles Clippers' with 94854640

# %% [markdown]
# 3.Thel lowest salary expenditure is team 'Philadelphia 76ers' with 30992894

# %%
high_sal_pos=df.groupby('Position')['Salary'].sum().reset_index()

# %%
plt.bar(x='Position',height='Salary',data=high_sal_pos,color='b')
for i in range(len(high_sal_pos)):
    plt.text(high_sal_pos['Position'][i], high_sal_pos['Salary'][i] + 1, str(high_sal_pos['Salary'][i]),
             ha='center',color='k')
plt.xticks(rotation=90)
plt.title('Salary Expenditure by Position')
plt.xlabel('Position')
plt.ylabel('Total Salary Expenditure')

plt.show()

# %% [markdown]
# 1.The position highest salary expenditure is C with 466377332

# %% [markdown]
# 5. Investigate if there's any correlation between age and salary, and represent it visually.

# %%
age_salary_corr = df[['Age', 'Salary']].corr()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Salary'])
plt.title('Correlation between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# 1.The Scatter plot shows a clear image about the age of employees and their salaries.

# %% [markdown]
# 2.This company more trusted with young employees and the average age of employee with different position is about 26 to 27 years old

# %% [markdown]
# 3.24-34 years old employee will get more salary than other age group employees.

# %% [markdown]
# 4.The yongest employee is about 19 years old

# %% [markdown]
# # findings

# %% [markdown]
# 1.A significant portion of employees are within the 30-40 age group, indicate a balanced mix of experience and youth.

# %% [markdown]
# 2.Older employees have higher salaries, likely due to experience and tenure.
